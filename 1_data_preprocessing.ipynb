# %%
! pip install chembl_webresource_client

# %%
# Import necessary libraries
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# Fetching Beta-lactamase Inhibitors

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
target = new_client.target
target_query = target.search('DNA Gyrase Inhibitor')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#      cross_references                                           organism  \
# 0                  []                           Streptococcus pneumoniae
# 1                  []                         Staphylococcus epidermidis
# 2                  []                              Staphylococcus aureus
# 3                  []                             Pseudomonas aeruginosa
# 4                  []  Streptococcus pyogenes serotype M3 (strain ATC...
# ...               ...                                                ...
# 6533               []                                       Homo sapiens
# 6534               []                                       Homo sapiens
# 6535               []                                       Homo sapiens
# 6536               []                                       Homo sapiens
# 6537               []                                       Mus musculus
#
#              pref_name  score  species_group_flag target_chembl_id  \
# ...

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL3038482'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df= pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 741                                               None             None
# 742  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 743  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 744  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 745  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %%
df.to_csv('dna_gyrase_inhibitor_bioactivity_data_raw.csv')

# %% [markdown]
# Handle Missing Data

# %%
df1= df[df.standard_value.notna()]
df1= df1[df.canonical_smiles.notna()]
df1
# Out:
# C:\Users\saman\AppData\Local\Temp\ipykernel_13952\98724113.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1= df1[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 741                                               None             None
# 742  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 743  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df1.canonical_smiles.unique())
df2= df1.drop_duplicates(['canonical_smiles'])
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 740                                               None             None
# 741                                               None             None
# 742  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 743  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 744  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# Data Preprocessing for Bioactivity Data

# %%
selection= ['molecule_chembl_id','canonical_smiles','standard_value']
df3= df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187677  C[C@H]1CCc2c(N3CCC(O)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 1         CHEMBL363449   CC1CCc2c(N3CCC(O)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 2              CHEMBL8         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 3         CHEMBL192226  CN1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn(/C=C\F)c3c2F)CC1
# 4         CHEMBL371124  CN1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn(/C=C/F)c3c2F)CC1
# ..                 ...                                                ...
# 740      CHEMBL5431772  COc1ccc2nccc(OC[C@H]3CC[C@H](NC(=O)c4cc(F)c(Br...
# 741      CHEMBL5429864  COc1ccc2nccc(OC[C@H]3CC[C@H](NC(=O)c4ccc(I)c(F...
# 742      CHEMBL5394250  COc1ccc2nccc(OC[C@@H]3CC[C@@H](NC(=O)c4cc(F)c(...
# 743      CHEMBL5406927  COc1ccc2nccc(OC[C@@H]3CC[C@@H](NC(=O)c4cc(F)c(...
# 744      CHEMBL5421348  COc1ccc2nccc(OC[C@@H]3CC[C@@H](NC(=O)c4ccc(I)c...
#
#     standard_value
# 0              5.0
# 1             10.0
# ...

# %%
df3.to_csv('DNA_gyrase_inhibitor_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# Labeling compounds as either being active, inactive or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
df3= pd.read_csv(r"C:\Users\saman\Desktop\Gyrase\DNA_gyrase_inhibitor_bioactivity_data_preprocessed.csv")

# %%
bioactivity_threshold = []
for i in df3.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187677  C[C@H]1CCc2c(N3CCC(O)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 1         CHEMBL363449   CC1CCc2c(N3CCC(O)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 2              CHEMBL8         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 3         CHEMBL192226  CN1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn(/C=C\F)c3c2F)CC1
# 4         CHEMBL371124  CN1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn(/C=C/F)c3c2F)CC1
# ..                 ...                                                ...
# 541      CHEMBL5431772  COc1ccc2nccc(OC[C@H]3CC[C@H](NC(=O)c4cc(F)c(Br...
# 542      CHEMBL5429864  COc1ccc2nccc(OC[C@H]3CC[C@H](NC(=O)c4ccc(I)c(F...
# 543      CHEMBL5394250  COc1ccc2nccc(OC[C@@H]3CC[C@@H](NC(=O)c4cc(F)c(...
# 544      CHEMBL5406927  COc1ccc2nccc(OC[C@@H]3CC[C@@H](NC(=O)c4cc(F)c(...
# 545      CHEMBL5421348  COc1ccc2nccc(OC[C@@H]3CC[C@@H](NC(=O)c4ccc(I)c...
#
#      standard_value     class
# 0               5.0    active
# ...

# %%
df4.to_csv('dna_gyrase_bioactivity_data_curated.csv', index=False)
